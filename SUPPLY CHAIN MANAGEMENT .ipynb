# %% [markdown]
# # Supply Chain Management:
#
#
# ### About Dataset:
# - Supply chain analytics involves collecting, analyzing, and interpreting data.
# - It is essential for optimizing product and service movement from suppliers to customers.
# - Applicable across industries like manufacturing, retail, healthcare, and logistics.
#
# ### Project Overview:
# - Objective: Build a **Supply Chain Management (SCM) Dashboard** using **Powerbi**.
# - Focus areas:
#   - **Inventory Management**: Monitor stock levels.
#   - **Order Fulfillment**: Track timely delivery and processing of orders.
#   - **Supplier Performance**: Evaluate suppliers' reliability and quality.
#   - **Transportation Efficiency**: Analyze shipping routes, costs, and carriers.
#   - **Cost Optimization**: Reduce overall supply chain costs through data-driven decisions.
#
#
# ### Import Imortant Libraries:

# %%
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r"C:\Users\ksvg7\Downloads\Supply Chain Management Project\supply_chain_data.csv")
data.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
data.shape
# Out:
# (100, 24)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %%
data.describe()
# Out:
#             Price  Availability  Number of products sold  Revenue generated  \
# count  100.000000    100.000000               100.000000         100.000000
# mean    49.462461     48.400000               460.990000        5776.048187
# std     31.168193     30.743317               303.780074        2732.841744
# min      1.699976      1.000000                 8.000000        1061.618523
# 25%     19.597823     22.750000               184.250000        2812.847151
# 50%     51.239831     43.500000               392.500000        6006.352023
# 75%     77.198228     75.000000               704.250000        8253.976921
# max     99.171329    100.000000               996.000000        9866.465458
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count    100.000000  100.000000        100.000000      100.000000
# mean      47.770000   15.960000         49.220000        5.750000
# std       31.369372    8.785801         26.784429        2.724283
# ...

# %%
data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %% [markdown]
# ### Importance of Inventory in Supply Chain:
# - **Customer Satisfaction**: Ensures products are available to meet customer demand.
# - **Cost Management**: Excess inventory ties up capital, while too little inventory can lead to stockouts and lost sales.
# - **Efficiency**: Helps optimize production schedules and minimize delays.

# %% [markdown]
# ### Checking the Missing Values:

# %%
m=data.isnull().sum()*100/len(data)
m
# Out:
# Product type               0.0
# SKU                        0.0
# Price                      0.0
# Availability               0.0
# Number of products sold    0.0
# Revenue generated          0.0
# Customer demographics      0.0
# Stock levels               0.0
# Lead times                 0.0
# Order quantities           0.0
# Shipping times             0.0
# Shipping carriers          0.0
# Shipping costs             0.0
# Supplier name              0.0
# Location                   0.0
# Lead time                  0.0
# Production volumes         0.0
# Manufacturing lead time    0.0
# Manufacturing costs        0.0
# Inspection results         0.0
# Defect rates               0.0
# Transportation modes       0.0
# Routes                     0.0
# Costs                      0.0
# dtype: float64

# %% [markdown]
# #### Handling Irregualrities:-
# - All the columns have correct datatypes
# - fix rows and columns
# - outliers
# - standarize
# - filter data
#
#
# #### 1. Fix Rows and Columns:

# %%
data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %% [markdown]
# - Here, we can see that there is price values with indefinite values after decimal.
# - So will replace these with only 2 values after the decimal point then it will be easier in price calculation and further analysis

# %%
data['Price'] = data['Price'].round(2)

# %%
data['Price'].value_counts()
# Out:
# Price
# 17.03    2
# 69.81    1
# 13.02    1
# 90.20    1
# 6.38     1
#         ..
# 8.02     1
# 63.45    1
# 2.40     1
# 92.56    1
# 68.52    1
# Name: count, Length: 99, dtype: int64

# %%
data['Revenue generated'] = data['Revenue generated'].round(2)

# %%
data['Revenue generated'].value_counts()
# Out:
# 8662.00    1
# 4256.95    1
# 7910.89    1
# 2633.12    1
# 8180.34    1
#           ..
# 2766.34    1
# 8318.90    1
# 6117.32    1
# 2686.46    1
# 9185.19    1
# Name: Revenue generated, Length: 100, dtype: int64

# %%
data['Shipping costs'] = data['Shipping costs'].round(2)

# %%
data['Shipping costs'].value_counts()
# Out:
# Shipping costs
# 4.07    2
# 8.63    2
# 6.58    2
# 6.60    2
# 7.29    2
#        ..
# 8.10    1
# 9.90    1
# 7.41    1
# 6.51    1
# 1.31    1
# Name: count, Length: 95, dtype: int64

# %%
data['Manufacturing costs'] = data['Manufacturing costs'].round(2)

# %%
data['Manufacturing costs'].value_counts()
# Out:
# 46.28    1
# 20.08    1
# 46.87    1
# 55.76    1
# 30.66    1
#         ..
# 51.63    1
# 39.29    1
# 59.43    1
# 10.53    1
# 38.07    1
# Name: Manufacturing costs, Length: 100, dtype: int64

# %% [markdown]
# #### Defect rates:
# - Refer to the percentage or proportion of defective items or products produced in a manufacturing or production process. It measures the quality and efficiency of the production process by indicating how many products do not meet the required quality standards or specifications.

# %%
data['Costs'] = data['Costs'].round(2)

# %%
data['Costs'].value_counts()
# Out:
# Costs
# 187.75    1
# 687.29    1
# 866.47    1
# 677.94    1
# 405.17    1
#          ..
# 880.08    1
# 764.94    1
# 123.44    1
# 762.46    1
# 210.74    1
# Name: count, Length: 100, dtype: int64

# %% [markdown]
# ## Understanding the Data:

# %%
data['Product type'].value_counts()
# Out:
# Product type
# skincare     40
# haircare     34
# cosmetics    26
# Name: count, dtype: int64

# %%
data['Customer demographics'].value_counts()
# Out:
# Customer demographics
# Unknown       31
# Female        25
# Non-binary    23
# Male          21
# Name: count, dtype: int64

# %%
data['Shipping carriers'].value_counts()
# Out:
# Shipping carriers
# Carrier B    43
# Carrier C    29
# Carrier A    28
# Name: count, dtype: int64

# %%
data['Location'].value_counts()
# Out:
# Location
# Kolkata      25
# Mumbai       22
# Chennai      20
# Bangalore    18
# Delhi        15
# Name: count, dtype: int64

# %%
data['Transportation modes'].value_counts()
# Out:
# Transportation modes
# Road    29
# Rail    28
# Air     26
# Sea     17
# Name: count, dtype: int64

# %%
data['Routes'].value_counts()
# Out:
# Routes
# Route A    43
# Route B    37
# Route C    20
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %% [markdown]
# ## OBSERVE THE AVERAGE COSTS FOR COLUMNS:

# %%
import pandas as pd

# Assuming your dataset is stored in a DataFrame named 'df'
columns_of_interest = [
    'Price', 'Number of products sold', 'Revenue generated', 
    'Order quantities', 'Shipping costs', 'Lead time',
 'Manufacturing costs', 'Defect rates', 'Costs']

# Create an empty dictionary to store results
stats_summary = {}

# Loop through each column and calculate the required statistics
for col in columns_of_interest:
    stats_summary[col] = {
        'Average': data[col].mean(),
        'Minimum': data[col].min(),
        'Maximum': data[col].max(),
        'Std Deviation': data[col].std()
    }

# Convert the dictionary to a DataFrame for better readability
summary_data = pd.DataFrame(stats_summary)

summary_data = summary_data.round(2)

# Transpose the DataFrame so that statistics are rows and columns are the features
summary_data = summary_data.T

# Reset index and give proper column names

summary_data = summary_data.reset_index()
summary_data.columns = ['Column', 'Average', 'Minimum', 'Maximum', 'Std Deviation']

# Display the summary table
print(summary_data)
# Out:
#                     Column  Average  Minimum  Maximum  Std Deviation
# 0                    Price    49.46     1.70    99.17          31.17
# 1  Number of products sold   460.99     8.00   996.00         303.78
# 2        Revenue generated  5776.05  1061.62  9866.47        2732.84
# 3         Order quantities    49.22     1.00    96.00          26.78
# 4           Shipping costs     5.55     1.01     9.93           2.65
# 5                Lead time    17.08     1.00    30.00           8.85
# 6      Manufacturing costs    47.27     1.09    99.47          28.98
# 7             Defect rates     2.28     0.02     4.94           1.46
# 8                    Costs   529.25   103.92   997.41         258.30

# %%
import pandas as pd

# Data extracted from the image
data1 = {
    "Column": [
        "Price",
        "Number of products sold",
        "Revenue generated",
        "Order quantities",
        "Shipping costs",
        "Lead time",
        "Manufacturing costs",
        "Defect rates",
        "Costs"
    ],
    "Average": [
        49.46,
        460.99,
        5776.05,
        49.22,
        5.55,
        17.08,
        47.27,
        2.28,
        529.25
    ],
    "Minimum": [
        1.70,
        8.00,
        1061.62,
        1.00,
        1.01,
        1.00,
        19.47,
        0.02,
        103.92
    ],
    "Maximum": [
        99.17,
        996.00,
        9866.47,
        96.00,
        9.93,
        30.00,
        99.47,
        4.94,
        997.41
    ],
    "Std Deviation": [
        31.17,
        303.78,
        2732.84,
        26.78,
        2.65,
        8.85,
        28.98,
        1.46,
        258.30
    ]
}

# Create a DataFrame
summary_df = pd.DataFrame(data1)

# Display the DataFrame
summary_df
# Out:
#                     Column  Average  Minimum  Maximum  Std Deviation
# 0                    Price    49.46     1.70    99.17          31.17
# 1  Number of products sold   460.99     8.00   996.00         303.78
# 2        Revenue generated  5776.05  1061.62  9866.47        2732.84
# 3         Order quantities    49.22     1.00    96.00          26.78
# 4           Shipping costs     5.55     1.01     9.93           2.65
# 5                Lead time    17.08     1.00    30.00           8.85
# 6      Manufacturing costs    47.27    19.47    99.47          28.98
# 7             Defect rates     2.28     0.02     4.94           1.46
# 8                    Costs   529.25   103.92   997.41         258.30

# %% [markdown]
# # UNIVARIATE ANALYSIS :

# %%
data['Product type'].value_counts()
# Out:
# Product type
# skincare     40
# haircare     34
# cosmetics    26
# Name: count, dtype: int64

# %%
labels = ['skincare','haircare','cosmetics']
sizes= [40,34,26]
explode=[0,0.01,0.01]

plt.figure(figsize=(5,5))
plt.pie(sizes,labels=labels,explode=explode,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# -  **skincare** and **haircare** has the highest demand

# %%
data['Customer demographics'].value_counts()
# Out:
# Customer demographics
# Unknown       31
# Female        25
# Non-binary    23
# Male          21
# Name: count, dtype: int64

# %%
labels = ['Unknown','Female','Non-binary','Male']
sizes= [31,25,23,21]
explode=[0,0.01,0.01,0.01]

plt.figure(figsize=(5,5))
plt.pie(sizes,labels=labels,explode=explode,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# #### Distribution of product prices:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data['Price'], bins=10, kde=True)
plt.title('Distribution of Product Prices')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# - Here, we can see that there is price range b/w 0-100
# - Most of product have prices from **0-20** and **60-100**
# - We can say that the most products are low or high priced

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data['Number of products sold'], bins=10, kde=True)
plt.title('Distribution of Number of products sold')
plt.xlabel('Number of products sold')
plt.show()

# %% [markdown]
# - Good amount of products have been sold

# %%
sns.kdeplot(x=data['Stock levels'])
plt.show()

# %%
sns.histplot(data['Shipping costs'], bins=10,kde=True)
plt.show()

# %%
data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
sns.boxplot(x=data['Manufacturing lead time'])
plt.show()

# %%
sns.histplot(data['Manufacturing costs'], bins=10,kde=True)
plt.show()

# %%
data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
sns.histplot(data['Costs'], bins=10,kde=True)
plt.show()

# %% [markdown]
# # BIVARIATE ANALYSIS:

# %% [markdown]
# 1. Product Type V/S Availability:

# %%
sns.barplot(x='Product type', y='Price', data=data)
plt.title('Product Type v/s Price')
plt.show()

# %% [markdown]
# - Cosmetics items have the higest price
#
# 2. Product Type v/s Number of products sold:

# %%
sns.barplot(x='Product type', y='Number of products sold', data=data)
plt.title('Product Type v/s Availability')
plt.show()

# %% [markdown]
# - As we can see that there is skincare and cosmetics are the most sold products there should be appropriate availability

# %% [markdown]
# 3. Product Type v/s Availability:

# %%
sns.barplot(x='Product type', y='Availability', data=data)
plt.title('Product Type v/s Availability')
plt.show()

# %% [markdown]
# 4. Number of products sold V/S Revenue generated

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Using Matplotlib
plt.scatter(x='Number of products sold', y='Revenue generated', data=data)
plt.xlabel('Number of products sold ')
plt.ylabel('Revenue generated')
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# 5. Product Type v/s Order Quantity:

# %%
sns.barplot(x='Product type', y='Order quantities', data=data)
plt.title('Bar Plot')
plt.show()

# %% [markdown]
# 6. Product Type v/s Customer Demographics:

# %%
sns.countplot(x='Product type', hue='Customer demographics', data=data)
plt.title('Product type v/s Customer demographics')
plt.show()

# %% [markdown]
# 7. Product Type v/s Shipping costs

# %%
# Assuming your DataFrame is named df and contains columns 'Product type' and 'Shipping costs'
plt.figure(figsize=(6, 6))

# Create the bar plot
sns.barplot(x='Product type', y='Shipping costs', data=data)

# Customize the plot
plt.xticks(rotation=45, ha='right')  # Rotate the x-axis labels if they overlap
plt.title('Shipping Costs by Product Type')
plt.xlabel('Product Type')
plt.ylabel('Shipping Costs')
# Out:
# Text(0, 0.5, 'Shipping Costs')

# %%
data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
plt.figure(figsize=(6, 6))

# Create the bar plot
sns.barplot(y='Revenue generated', x='Location', data=data)

# Customize the plot
#plt.xticks(rotation=45, ha='right')  # Rotate the x-axis labels if they overlap
plt.title('Revenue generated by Location')
plt.ylabel('Revenue generated')
plt.xlabel('Location')
plt.show()

# %% [markdown]
# - we can see that there is amlmost all the cities which are generating revenue whereas "Mumbai" has the highest

# %% [markdown]
# # Now we will  optimize various aspects of the supply chain
#
# ### 1. Inventory Levels:

# %%
# Create the bar plot
sns.barplot(x='Product type', y='Stock levels', data=data)

# Customize the plot
#plt.xticks(rotation=45, ha='right')  # Rotate the x-axis labels if they overlap
plt.title('Product type by Stock levels')
plt.ylabel('Product type')
plt.xlabel('Stock levels')
plt.show()

# %%
sns.lineplot(x='SKU', y='Stock levels', data=data)
plt.title('SKU v/s Stock levels')
plt.show()

# %% [markdown]
# ### 2.Order Fulfillment:

# %%
# Create the bar plot
sns.barplot(x='Product type', y='Shipping times', data=data)

# Customize the plot
#plt.xticks(rotation=45, ha='right')  # Rotate the x-axis labels if they overlap
plt.title('Product type by Shipping times')
plt.ylabel('Product type')
plt.xlabel('Shipping times')
plt.show()

# %%
# Create the bar plot
sns.barplot(x='Product type', y='Order quantities', data=data)

# Customize the plot
#plt.xticks(rotation=45, ha='right')  # Rotate the x-axis labels if they overlap
plt.title('Product type by Order quantities')
plt.ylabel('Product type')
plt.xlabel('Order quantities')
plt.show()

# %% [markdown]
# ### 3. Supplier Performance:

# %%
sns.boxplot(x='Supplier name', y='Lead time', data=data)
plt.title('Supplier name v/s Lead time')
plt.show()

# %%
sns.boxplot(x='Supplier name', y='Defect rates', data=data)
plt.title('Supplier name v/s Defect rates')
plt.show()

# %%
data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %% [markdown]
# ### 4. Transportation Efficiency:

# %%
# Assuming your DataFrame is named df and contains columns 'Routes', 'Transportation modes', and 'Transportation Costs'
plt.figure(figsize=(6, 6))

# Bar plot for Routes vs. Transportation Costs
sns.barplot(x='Routes', y='Costs', data=data)
plt.xticks(rotation=45, ha='right')  # Rotate the x-axis labels for readability
plt.title('Costs by Routes')
plt.xlabel('Routes')
plt.ylabel('Costs')
plt.show()

# Bar plot for Transportation Modes vs. Transportation Costs
plt.figure(figsize=(6, 6))
sns.barplot(x='Transportation modes', y='Costs', data=data)
plt.xticks(rotation=45, ha='right')
plt.title('Costs by Transportation Modes')
plt.xlabel('Transportation Modes')
plt.ylabel('Costs')
plt.show()

# %% [markdown]
# ### 5. Overall Supply Chain Costs:

# %%
# Assuming you have the total costs for each component
costs = {
    'Manufacturing costs': data['Manufacturing costs'].sum(),
    'Shipping costs': data['Shipping costs'].sum(),
    'Costs': data['Costs'].sum()
}

explode=[0,0.01,0.1]
# Extract labels and values
labels = list(costs.keys())
values = list(costs.values())

# Plotting the pie chart
plt.figure(figsize=(7, 7))
plt.pie(values,explode= explode ,labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Breakdown of Supply Chain Costs')
plt.show()

# %% [markdown]
# ### 6. Revenue Analysis:

# %%
sns.boxplot(x='Product type', y='Revenue generated', data=data)
plt.title('Product type v/s Revenue generated')
plt.show()

# %% [markdown]
# ### 7. Demand Analysis:

# %%
# Example of line plot: Number of products sold vs Product type
plt.figure(figsize=(6, 6))
sns.lineplot(x='Product type', y='Number of products sold', data=data, marker='o')

plt.title('Demand Analysis: Number of Products Sold by Product Type')
plt.xlabel('Product Type')
plt.ylabel('Number of Products Sold')

plt.xticks(rotation=45, ha='right')  # Rotate labels for better readability
plt.show()

# %% [markdown]
# ### 8. Cost Efficiency:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data: Replace these with your actual data columns
product_types = data['Product type']
shipping_costs = data['Shipping costs']
manufacturing_costs = data['Manufacturing costs']
transportation_costs = data['Costs']

# Number of product types
n_products = len(product_types)

# Set the figure size
plt.figure(figsize=(20, 20))

# Create an array of positions for the x-axis
bar_width = 0.5
bar_positions = np.arange(n_products)

# Plot each cost category as a stacked bar
plt.bar(bar_positions, shipping_costs, bar_width, label='Shipping Costs', color='lightblue')
plt.bar(bar_positions, manufacturing_costs, bar_width, bottom=shipping_costs, label='Manufacturing Costs', color='lightgreen')
plt.bar(bar_positions, transportation_costs, bar_width, bottom=shipping_costs + manufacturing_costs, label='Transportation Costs', color='salmon')

# Customize the plot
plt.xlabel('Product Type')
plt.ylabel('Total Costs')
plt.title('Stacked Costs by Product Type')
plt.xticks(bar_positions, product_types, rotation=90, ha='right')  # Rotate labels for better readability
plt.legend()

# Display the plot
plt.tight_layout()  # Adjust layout for better fit
plt.show()

# %% [markdown]
# ## 1.  Inventory Levels:

# %%
data['Incoming Inventory'] = data['Order quantities'] * (data['Lead times'] / data['Manufacturing lead time'])

# %%
data['Defective Inventory'] = data['Stock levels'] * data['Defect rates']

# %%
# Calculate Current Inventory
data['Current Inventory'] = (data['Stock levels'] +
                           data['Incoming Inventory'] -
                           data['Number of products sold'] -
                           data['Defective Inventory'])

# %%
# Calculate Inventory Costs
data['Inventory Costs'] = (
    data['Stock levels'] * data['Price'] +
    data['Shipping costs'] +
    data['Costs'] +
    data['Manufacturing costs'])

# %% [markdown]
# ### Inventory Trend Overtime:

# %%
# Create a sequential index to represent time
data['Time Period'] = range(1, len(data) + 1)

# Calculate Current Inventory
data['Current Inventory'] = (
    data['Stock levels'] + data['Incoming Inventory'] -
    data['Number of products sold'] - data['Defective Inventory']
)

# Group by Time Period to see trends
trends = data.groupby('Time Period').agg(
    Total_Current_Inventory=('Current Inventory', 'sum'),
    Total_Number_Sold=('Number of products sold', 'sum'),
    Total_Incoming_Inventory=('Incoming Inventory', 'sum'),
    Total_Defective_Inventory=('Defective Inventory', 'sum')
).reset_index()

# Plot Inventory Trends
plt.figure(figsize=(12, 6))
plt.plot(trends['Time Period'], trends['Total_Current_Inventory'], marker='o', label='Total Current Inventory')
plt.plot(trends['Time Period'], trends['Total_Number_Sold'], marker='o', label='Total Number Sold')
plt.plot(trends['Time Period'], trends['Total_Incoming_Inventory'], marker='o', label='Total Incoming Inventory')
plt.plot(trends['Time Period'], trends['Total_Defective_Inventory'], marker='o', label='Total Defective Inventory')

plt.title('Inventory Trends Over Time')
plt.xlabel('Time Period')
plt.ylabel('Inventory Metrics')
plt.xticks(trends['Time Period'])
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# - There are significant negative spikes in the total current inventory, suggesting periods of high demand where the available stock dips drastically.
# - Sales show extreme peaks at various intervals, indicating that demand for products is highly variable. There are periods of high sales followed by lower periods.
# - The incoming inventory seems to be relatively stable but fails to react dynamically to the drastic changes in current inventory and sales, causing mismatches between supply and demand.
# - There is a moderate presence of defective inventory throughout the time period, though not excessive. However, spikes in defective inventory can affect overall supply chain performance, potentially leading to order fulfillment delays and additional costs.

# %%
# Plotting the bar graph for Current Inventory
plt.figure(figsize=(10, 5))
plt.bar(data['Product type'], data['Current Inventory'], color='skyblue')
plt.xlabel('Products')
plt.ylabel('Current Inventory')
plt.title('Current Inventory of Products')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Supplier Performance Analysis:
# - Metric: Evaluate the performance of different suppliers based on lead times, defect rates, and on-time delivery.
# - Objective: Identify the best and worst-performing suppliers.

# %%
# Calculate Total Delivery Time
data['Total Delivery Time'] = data['Lead time'] + data['Shipping times']

# Calculate Average Delivery Time by Supplier
average_delivery_time_by_supplier = data.groupby('Supplier name')['Total Delivery Time'].mean().reset_index()

# Rename the column for clarity
average_delivery_time_by_supplier.rename(columns={'Total Delivery Time': 'Average Delivery Time'}, inplace=True)
print(average_delivery_time_by_supplier)
# Out:
#   Supplier name  Average Delivery Time
# 0    Supplier 1              20.851852
# 1    Supplier 2              24.045455
# 2    Supplier 3              25.333333
# 3    Supplier 4              20.777778
# 4    Supplier 5              24.277778

# %% [markdown]
# ### Results:
#
# - **Supplier 1 (20.85 days)** and **Supplier 4 (20.78 days)** have very close delivery times. Both suppliers could be considered for urgent orders due to their faster delivery times.
# - **Supplier 2 (24.05 days)** and **Supplier 5 (24.28 days)** have similar average delivery times, falling in the middle range. While not the fastest, their consistency could be leveraged for orders that do not require urgent fulfillment.
# - If reducing lead times is a priority, **Supplier 4 and Supplier 1** should be considered for critical operations.
# - This suggests that Supplier 3 may be less efficient or operates with longer lead times compared to the other suppliers (require closer management, negotiation with suppliers)

# %%
# Group by Time Period and calculate total Incoming and Defective Inventory
grouped_df = data.groupby('Time Period').agg({
    'Incoming Inventory': 'sum',
    'Defective Inventory': 'sum'
}).reset_index()

# Calculate Defect Rate
grouped_df['Defect Rates'] = (grouped_df['Defective Inventory'] / grouped_df['Incoming Inventory']) * 100

# Output the defect rates over time
print("Defect Rates Over Time:")
print(grouped_df[['Time Period', 'Defect Rates']])

# Example visualization (optional)

plt.plot(grouped_df['Time Period'], grouped_df['Defect Rates'], marker='o')
plt.xlabel('Time Period')
plt.ylabel('Defect Rate (%)')
plt.title('Defect Rate Over Time')
plt.xticks(rotation=90)
plt.show()
# Out:
# Defect Rates Over Time:
#     Time Period  Defect Rates
# 0             1     56.669974
# 1             2    695.312447
# 2             3     14.054091
# 3             4    256.207631
# 4             5     28.085531
# ..          ...           ...
# 95           96    129.737371
# 96           97  11349.939766
# 97           98   2656.566086
# 98           99   5137.682499
# 99          100      8.064195
#
# [100 rows x 2 columns]

# %% [markdown]
# - The spikes indicate periods of higher defect rates, potentially due to poor supplier performance or quality control issues. Regular monitoring and evaluation of suppliers should be implemented to address the variability in defect rates.
# - High defect rates can disrupt inventory levels
# - Improve quality assurance processes before shipping to reduce delays in order fulfillment.
# - Periods of high defects are likely increasing overall supply chain costs due to rework, returns, and additional shipping costs.

# %%
# DEFECT RATE v/s SUPPLIERS:
sns.boxplot(y='Defect rates', x='Supplier name', data=data)
plt.title('Defect rates v/s Supplier name')
plt.show()

# %% [markdown]
# ### Results:
# - Supplier 3 has the highest median defect rate, indicating that products from this supplier tend to have more defects compared to others.
# - Supplier 1 appears to have the lowest median defect rate, suggesting they may be the most reliable in terms of product quality.
#
# #### Overall Quality Assessment:
#
# - Based on the median values and the spread of the defect rates, you could prioritize suppliers for better quality assurance. Suppliers with lower medians and less variability in defect rates are preferable.
#
# #### Reliable Suppliers:
#
# - Continue Orders With: Supplier 1 (best option), possibly Supplier 2 if more consistent.
# - Reassess or Negotiate: Suppliers 3 and 5, and discuss quality improvement measures.
#
# #### Supplier Evaluation:
# - Consider conducting a deeper analysis of Supplier 3 to identify reasons for the higher defect rates. Look into their production processes, quality control measures, and historical performance.
# #### Quality Improvement Initiatives:
# - Collaborate with suppliers that show higher defect rates to implement quality improvement programs

# %%
data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs', 'Incoming Inventory',
#        'Defective Inventory', 'Current Inventory', 'Inventory Costs',
#        'Time Period', 'Total Delivery Time'],
#       dtype='object')

# %% [markdown]
# ## 3. Cost Efficiency Breakdown:
# - Metric: Analyze the cost efficiency for each product by breaking down the costs (manufacturing, shipping, transportation) to assess where the most money is spent.
# - Objective: Identify areas where cost reductions can be made.

# %%
# Set the figure size
plt.figure(figsize=(6, 6))

# Create stacked bar plot
plt.bar(data['Product type'], data['Manufacturing costs'], label='Manufacturing costs', color='steelblue')
plt.bar(data['Product type'], data['Shipping costs'], bottom=data['Manufacturing costs'], label='Shipping costs', color='lightgreen')
plt.bar(data['Product type'], data['Costs'], 
        bottom=data['Manufacturing costs'] + data['Shipping costs'], label='Costs', color='salmon')

# Add title and labels
plt.title('Cost Efficiency Breakdown by Product Type')
plt.xlabel('Product Type')
plt.ylabel('Cost ($)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Analyze Transportation Costs:
#
# - Since transportation seems to be a significant cost driver, further analysis of transportation logistics and strategies to reduce these costs should be prioritized.
# - The 90% of cost spending on transportation from above pie chart we can see
# #### what we can do:
# - For transportation,optimizing routes
# - Negitiate with better rates with carriers
# - Use local,suppliers or suppliers with low transporatation costs and distribtution center
# - Use the better mode which uses the less fuel and provides efficiency
# - plan shipments better
# - reduce excess inventory movement
# - optimize transportation capacity.

# %% [markdown]
# ### 4. Lead Time vs. Revenue Impact:
# - Metric: Investigate how changes in lead times affect overall revenue generation.
# - Objective: Assess whether longer lead times are causing delayed sales and revenue losses.

# %%
# Set up the scatter plot with regression line
plt.figure(figsize=(6, 6))
sns.regplot(x='Lead time', y='Revenue generated', data=data, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})

# Adding titles and labels
plt.title('Lead Time vs. Revenue Impact', fontsize=16)
plt.xlabel('Lead Time (Days)', fontsize=14)
plt.ylabel('Revenue Generated', fontsize=14)
plt.grid()

# Show the plot
plt.show()

# %% [markdown]
# ### Results :
# - No clear relationship between lead time and revenue exists, other factors might be playing a more critical role in influencing revenue, such as product type, customer demand, or market conditions.

# %% [markdown]
# ### 5. Defect Rate Analysis:
# - Metric: Analyze the percentage of defective products from each supplier or for each product type.
# - Objective: Understand which products or suppliers are contributing most to quality issues.

# %%
# Grouping by Product Type and calculating average defect rate
average_defect_rate = data.groupby('Product type')['Defect rates'].mean().reset_index()

# Plotting
plt.figure(figsize=(5, 5))
plt.bar(average_defect_rate['Product type'], average_defect_rate['Defect rates'], color='lightcoral')
plt.title('Average Defect Rate by Product Type')
plt.xlabel('Product Type')
plt.ylabel('Defect Rate (%)')
plt.ylim(0, max(average_defect_rate['Defect rates']) + 1)  # Adding some space above max
plt.axhline(0, color='black',linewidth=0.8, ls='--')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ### Results:
# - Haircare products have the highest defect rate, hovering above 2.5%.
# -  Both cosmetics and skincare products have a slightly lower defect rate, approximately 2%. However, the rates are still significant and could be impacting product quality and customer satisfaction.
#
#
# #### Conclusions:
# - Since haircare products have the highest defect rate, they should be the primary focus for **quality control improvements.** Investigate the manufacturing process, supplier quality, or packaging standards to reduce defects in this product line.
# - Implement Stricter Quality Control Measures : This could include automated defect detection systems or more frequent inspections during production.
# - The supply chain can be optimized for better product quality, leading to reduced returns, increased customer satisfaction, and enhanced profitability.

# %% [markdown]
# ### 7. Customer Segmentation Analysis:
# - Metric: Perform segmentation based on customer demographics (e.g., gender, location, purchase history).
# - Objective: Identify which customer segments are generating the most revenue and adjust marketing strategies accordingly.

# %%
grouped_data = data.groupby(['Customer demographics', 'Location']).sum().reset_index()

# %%
# Pivot the data for the heatmap
heatmap_data = grouped_data.pivot(index='Customer demographics', columns='Location', values='Revenue generated')

# Create the heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="YlGnBu", cbar_kws={'label': 'Revenue ($)'})
plt.title('Revenue Generated by Customer demographics and Locations')
plt.ylabel('Gender')
plt.xlabel('Location')
plt.show()

# %% [markdown]
# ## Results:
# - The locations generating the highest revenue are **Chennai, Kolkata, Mumbai,** and **Delhi**, with customer demographics including **Unknown, Female,** and **Non-Binary**.
#
# - The locations generating the lowest revenue are **Bangalore, Delhi,** and **Chennai**, with customer demographics primarily in the **Unknown** and **Non-Binary** categories.

# %% [markdown]
# ## 8. Route Efficiency:
# - Metric: Analyze how efficient different sales channels are in generating revenue compared to costs.
# - Objective: Identify the most cost-effective channels for future investments.

# %%
# Bar plot with legend outside the plot
sns.barplot(data=data, x='Routes', y='Revenue generated', hue='Routes', palette='Set2')

# Add labels and title
plt.title('Revenue by Routes (Bar Plot)')
plt.xlabel('Routes')
plt.ylabel('Revenue ($)')
plt.grid(True)

# Place the legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()


# Bar plot with legend outside the plot
sns.barplot(data=data, x='Routes', y='Costs', hue='Routes', palette='Set2')

# Add labels and title
plt.title('Costs by Routes')
plt.xlabel('Routes')
plt.ylabel('Costs')
plt.grid(True)

# Place the legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# ## Results:
#
# #### Route Efficiency:
# - Routes A and C are the most efficient routes as they are generating high revenue while incurring low transportation costs. This indicates that these routes are more profitable and could be prioritized for future business operations.
#
#
# #### Focus for Profit Maximization:
# - To maximize overall profits, the company should consider replicating the strategies used in routes A and C to improve efficiency on other routes like B, potentially leading to reduced costs and increased revenue.

# %% [markdown]
# ## 9. Lead Time Impact on Order Fulfillment:
# - Metric: Analyze how sales, costs, and other variables are distributed across different geographic regions.
# - Objective: Identify regions with high demand, low costs, or supply chain bottlenec

# %%
# Calculate Total Orders
total_orders = data['Order quantities'].sum()

# Calculate On-Time Orders
data['On-Time'] = data['Shipping times'] <= data['Lead times']
on_time_orders = data[data['On-Time']]['Order quantities'].sum()

# Calculate On-Time Fulfillment Rate
on_time_fulfillment_rate = (on_time_orders / total_orders) * 100

# Print results
print(f'Total Orders: {total_orders}')
print(f'On-Time Orders: {on_time_orders}')
print(f'On-Time Fulfillment Rate: {on_time_fulfillment_rate:.2f}%')

# Plotting
categories = ['Total Orders', 'On-Time Orders']
values = [total_orders, on_time_orders]

plt.figure(figsize=(5, 5))
plt.bar(categories, values, color=['skyblue', 'lightgreen'])
plt.title('Order Fulfillment Overview \n')
plt.ylabel('Number of Orders')
plt.ylim(0, max(values) + 50)  # Set y-axis limit for better visibility
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding value annotations
for i, value in enumerate(values):
    plt.text(i, value + 5, str(value), ha='center', va='bottom')

plt.show()
# Out:
# Total Orders: 4922
# On-Time Orders: 4199
# On-Time Fulfillment Rate: 85.31%

# %% [markdown]
# ### Results:
# - The business has a strong on-time fulfillment rate of over **85%**, which is a **positive indicator of efficiency and customer satisfaction.**
# - However, there is room for improvement, as about **14.69%** of orders are not delivered on time, which could lead to customer dissatisfaction or lost opportunities for repeat business.
# - Focusing on **reducing delays and improving delivery processes** could help boost the on-time fulfillment rate and enhance overall operational performance.

# %%
data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs', 'Incoming Inventory',
#        'Defective Inventory', 'Current Inventory', 'Inventory Costs',
#        'Time Period', 'Total Delivery Time', 'On-Time'],
#       dtype='object')

# %% [markdown]
# ## 10. Efficient Mode for Transportation :

# %%
# Calculate transit time
data['Transit Time'] = data['Total Delivery Time'] - data['Lead time']

# Group by Shipping Carrier to get average transit time
avg_transit_time = data.groupby('Shipping carriers')['Transit Time'].mean()

print(avg_transit_time)
# Out:
# Shipping carriers
# Carrier A    6.142857
# Carrier B    5.302326
# Carrier C    6.034483
# Name: Transit Time, dtype: float64

# %%
# 1. Bar Plot for Transportation Costs by Mode
plt.figure(figsize=(3, 3))
sns.barplot(x='Transportation modes', y='Costs', data=data, palette='Set2')
plt.title('Costs by Mode \n')
plt.xlabel('Transportation Modes')
plt.ylabel('Costs ($)')
plt.show()

# 2. Box Plot for Shipping Times by Mode
plt.figure(figsize=(3, 3))
sns.boxplot(x='Transportation modes', y='Shipping times', data=data, palette='Set1')
plt.title('Shipping Times by Transportation Mode\n')
plt.xlabel('Transportation Modes')
plt.ylabel('Shipping Time (days)')
plt.show()

# %% [markdown]
# ### Visualize costs vs time across different transportation modes

# %%
# FacetGrid plot to visualize costs vs time across different transportation modes
g = sns.FacetGrid(data, col="Transportation modes", height=3)
g.map(sns.barplot, "Shipping times", "Costs",palette='Set2')
g.add_legend()
plt.subplots_adjust(top=0.85)
g.fig.suptitle('Costs vs Shipping Times by Mode \n')
plt.show()

# %% [markdown]
# ###  Mode Optimization
# - Choose the optimal transportation mode based on order type:
#   - Use **air** for high-priority, small-volume shipments that require fast delivery.
#   - Use **sea** for bulk, non-urgent shipments to minimize costs.
#   - Use **rail** for mid-sized loads over long distances where time is important but cost needs control.
#   - Use **road** for short-distance deliveries or the "last mile" of deliveries.
#
# ####  Recommendations:
# - Optimize transportation modes based on urgency, volume, and cost.
# - Consolidate shipments and optimize routing to reduce transportation time and costs.
# - Leverage technology for real-time tracking, automation, and decision-making.
# - Negotiate with carriers and adopt sustainable practices for long-term cost reduction.
# - Analyze performance data continuously to refine transportation strategies.

# %%
data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs', 'Incoming Inventory',
#        'Defective Inventory', 'Current Inventory', 'Inventory Costs',
#        'Time Period', 'Total Delivery Time', 'On-Time', 'Transit Time'],
#       dtype='object')

# %% [markdown]
# ### Cost Distribution by Type and Supply Chain Costs Overtime:

# %%
## COST DISTRIBUTION BY TYPE:
cost_distribution = data.groupby('Product type')['Costs'].sum()
print(cost_distribution)
# Out:
# Product type
# cosmetics    13366.41
# haircare     17328.84
# skincare     22229.32
# Name: Costs, dtype: float64

# %%
data['Total Defect Cost'] = data['Defective Inventory'] * data['Defect rates']

# %%
# Aggregating costs over time periods
data['Total_Supply_Chain_Cost'] = data['Manufacturing costs'] + data['Shipping costs'] + data['Inventory Costs'] + data['Total Defect Cost']

# Grouping by time period to calculate cost over time
cost_over_time = data.groupby('Time Period')['Total_Supply_Chain_Cost'].sum().reset_index()

# %%
# Grouping by 'Time Period' and summing up costs over time
cost_over_time = data.groupby('Time Period')['Total_Supply_Chain_Cost'].sum().reset_index()

# Plotting the data
plt.figure(figsize=(6, 6))
plt.plot(cost_over_time['Time Period'], cost_over_time['Total_Supply_Chain_Cost'], marker='o', color='green', linestyle='-', label='Total Supply Chain Cost')
plt.xlabel('Time Period')
plt.ylabel('Total Supply Chain Cost')
plt.title('Supply Chain Costs Over Time')
plt.grid(True)
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Shipping time V/S Carriers and Transportation Costs:

# %%
# Bar plot showing average shipping time for each carrier
sns.barplot(data=data, x='Shipping carriers', y='Shipping times', palette='Set2')

# Add labels and title
plt.title('Shipping Time by Carrier\n')
plt.xlabel('Carrier')
plt.ylabel('Shipping Time (days)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)

plt.show()


sns.barplot(data=data, x='Shipping carriers', y='Costs', palette='Set2')

# Add labels and title
plt.title('Costs by Carrier\n')
plt.xlabel('Carrier')
plt.ylabel('Costs')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)

plt.show()

# %%
data.to_csv("SUPPLY_CHAIN.csv")
